# %%
# %run process_slides.py

# %%
path_arg = "./slides"
tesseract_path_arg = r"C:\Program Files\Tesseract-OCR\tesseract.exe"
out_path_arg = "./temp"

# %%
slidesearcher = make_slide_searcher(path_arg, tesseract_path_arg, out_path_arg)

# %%
slidesearcher.get_top_k("Accumulators", 5)
# Out:
# Iterators are Classes
#
# ```python
# class RangeIterator(object):
#     """Iterator class for squares of a range"""
#
#     # Attribute _limit: end of range
#     # How far to go
#
#     # Attribute _pos: current spot of iterator
#     # How far we are
#
#     def __next__(self):
#         """Returns the next element"""
#         if self.__pos >= self._limit:
#             raise StopIteration()
#         else:
#             value = self._pos * self._pos
#             self._pos += 1
#             return value
# ```
#
# Generators
# <PIL.Image.Image image mode=RGB size=720x540>
# 42
# Models in Assignment 7:
# - Models are often subclasses of GObject.
# - They have a built-in draw method.
# - Models can include groups of other models.
# - An example of this is the rockets in pyro.py.
# - Each rocket is a model.
# - However, the entire list of rockets is also considered a model.
# - The update() method can change both individual rockets and the entire list.
# - There are several model classes in the assignment.
# - The Ship class is used to animate the player.
# - The Alien class is used to represent an alien.
#
# GUL Applications 33
# <PIL.Image.Image image mode=RGB size=720x540>
# 33
# MVC in this Course:
# Model-View-Controller (MVC) is a software architectural pattern used in this course. It separates the application into three main components: the model, the view, and the controller.
#
# A3: Color classes:
# In this assignment, you will work with color classes. The adapp.py file will handle RGB, CMYK, and HSV color models. These color classes will be hidden from the user.
#
# A4: Turtle, Pen:
# In assignment A4, you will work with the Turtle and Pen classes. These classes will be used to create graphical objects and perform various drawing operations.
#
# A4: Functions in a4.py:
# The a4.py file will contain various functions. The window will serve as the view in this assignment, and there is no need for additional classes.
#
# A6: Player, Board:
# In assignment A6, you will work with the Player and Board classes. The game data will always be stored in the model, and these classes will drive the program forward.
#
# AT: Ship, Alien, etc.:
# In the AT (Advanced Topics) section, you will work with classes such as Ship, Alien, and others. These classes will represent different shapes and geometries and will be the main focus of the assignment.
#
# 1114/23, GUL Applications 29:
# These numbers and text seem to be unrelated to the previous content. Please provide more context or clarify the meaning behind them.
# <PIL.Image.Image image mode=RGB size=720x540>
# 29
# What Happens on a Function Call?
#
# When a function is called, several steps are executed in order to execute the code within the function. Let's break down the process:
#
# 1. Code Execution: The code within the function is executed line by line. In this case, the function `range2iter` is defined with a parameter `n`.
#
# 2. Heap Primitives: The function may use heap primitives, which are data structures used for memory allocation. These primitives can be used to store and manipulate data within the function.
#
# 3. Use of `ar`: It seems that `ar` is a variable or object being used within the function. However, without further context, it is difficult to determine its purpose.
#
# 4. `def range2iter(n):`: This line defines the function `range2iter` with a parameter `n`. The colon at the end indicates the start of the function's code block.
#
# 5. `global`: The `global` keyword is used to indicate that the variable `x` is a global variable, meaning it can be accessed and modified outside of the function.
#
# 6. `for x in range(n):`: This line starts a loop that iterates over a range of numbers from 0 to `n-1`. The loop variable `x` takes on each value in the range.
#
# 7. `range2iter(n)`: This line seems to be a typo or an error. It is calling the `range2iter` function recursively with the same parameter `n`. This may result in an infinite loop.
#
# 8. `yield x*x`: The `yield` keyword is used to create a generator function. It returns the square of the current value of `x` and pauses the execution of the function until the next value is requested.
#
# 9. `a = [2, iadigenerator]`: This line assigns a list `[2, iadigenerator]` to the variable `a`. However, the term `iadigenerator` is not clear and may be a typo or an error.
#
# 10. `Print('Ended loop for '+str(x))`: This line prints a message indicating the end of the loop for the current value of `x`. However, the correct function name should be `print` instead of `Print`.
#
# 11. `range2iter(3)`: This line calls the `range2iter` function with the argument `3`. This will execute the code within the function and return a generator object.
#
# 12. `rangeziter(3)`: This line seems to be a typo or an error. It is calling a non-existent function `rangeziter` with the argument `3`.
#
# 13. `Frames`: It is unclear what is meant by "Frames" in this context. It may refer to a concept related to function calls or execution, but without further information, it is difficult to determine its exact meaning.
#
# 14. `next(a)`: This line calls the `next` function on the generator object `a`. It retrieves the next value from the generator.
#
# 15. `<crist <ea0k`: This text appears to be a garbled or corrupted part of the slide and does not provide any meaningful information.
#
# 16. `'Step 3 of 20. Forwaa > Lasts line that has just executed => next line to execute'`: This text seems to be a comment or explanation related to the execution of code. It indicates that the current step is the third out of twenty and suggests that the next line to execute is the last line that has just executed.
#
# 17. `Generators`: This term refers to a type of function that returns an iterator object. Generators are used to create iterable sequences of values, which can be useful for memory efficiency and lazy evaluation.
#
# Overall, the function `range2iter` appears to be a generator function that yields the squares of numbers in a given range. However, there are some typos and unclear parts in the provided code that need to be addressed for proper execution.
# <PIL.Image.Image image mode=RGB size=720x540>
# 50
# Checking Input: Keyboard, Mouse/Touch
#
# - is_key_down(key):
#   - Returns True if the key is currently being pressed.
#   - The key is represented as a string ('a' or 'space').
#   - The position of the key press is stored as a Point2 object.
#   - Returns None if no touch is detected.
#   - An empty string means any key.
#
# - is_key_pressed(key):
#   - Returns True if the key was pressed in the current frame.
#   - Returns True if a touch was pressed.
#   - Returns False if the key was not pressed in the previous frame.
#   - Returns False if no touch was detected in the previous frame.
#
# - is_key_released(key):
#   - Returns True if the key was released in the current frame.
#   - Returns True if a touch was released.
#   - Returns False if the key was being pressed in the previous frame.
#   - Returns False if a touch was detected in the previous frame.
# <PIL.Image.Image image mode=RGB size=720x540>
# 23
