# %%
# %run process_slides.py

# %%
path_arg = "./slides"
tesseract_path_arg = r"C:\Program Files\Tesseract-OCR\tesseract.exe"
out_path_arg = "./temp"

# %%
slidesearcher = make_slide_searcher(path_arg, tesseract_path_arg, out_path_arg)
# Out:
# modules.json: 100%|██████████| 349/349 [00:00<00:00, 347kB/s]
# c:\Users\bhatn\AppData\Local\Programs\Python\Python311\Lib\site-packages\huggingface_hub\file_download.py:149: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\bhatn\.cache\huggingface\hub\models--sentence-transformers--msmarco-MiniLM-L6-cos-v5. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to see activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
# ...

# %%
slidesearcher.get_top_k("Model-View-Controller (MVC) pattern", 5)
# Out:
# Summary: The slide discusses the concept of click types and how to measure the speed of clicks. It suggests using a double click as a measure of two fast clicks and questions if it is fast enough. It proposes counting the number of fast clicks and adding an attribute called "clicks" that resets to 0 if the clicks are not fast enough. Additionally, it suggests tracking the time the click speed is pressed by adding an attribute called "time" that is set to 0 when the mouse is released and increments when the click is not pressed. The slide also mentions checking the time when the next click is pressed.
# <PIL.Image.Image image mode=RGB size=720x540>
# 24
# ...
